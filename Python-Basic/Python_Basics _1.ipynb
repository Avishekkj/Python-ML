# %% [markdown]
# # Python Basics

# %% [markdown]
# image![image.png](attachment:image.png)

# %%
fname = input("Input your First Name : ")
lname = input("Input your Last Name : ")
print ("Hello  " + ''.join(reversed(fname)) + " " + ''.join(reversed(lname)))
# Out:
# Input your First Name : firstname
# Input your Last Name : lastname
# Hello  emantsrif emantsal

# %%
pi = 22/7
r= 6.0
V= 4.0/3.0*pi* r**3
print('The volume of the sphere is: ',V)
# Out:
# The volume of the sphere is:  1056.0

# %% [raw]
# #####  TASK 2#######

# %%
values = input("Input some comma seprated numbers : ")
list = values.split(",")
print('List is : ', list)
# Out:
# Input some comma seprated numbers : 4,6,43,345
# List :  ['4', '6', '43', '345']

# %%
for i in range(6):
    for j in range(i):
        print("* ", end='')
    print("")
for i in range(6, 0, -1):
    for j in range(0, i - 2):
        print("* ", end='')
    print("")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
str = input("Enter a string : ")
print(''.join(reversed(str)))
# Out:
# Enter a string : reverse
# esrever

# %%
print("WE, THE PEOPLE OF INDIA," + "\n\t"  +" having solemnly resolved to constitute India into a SOVEREIGN, !" +"\n\t\t" +
      " SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC "+ "\n\t\t" + " and to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA,
# 	 having solemnly resolved to constitute India into a SOVEREIGN, !
# 		 SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 		 and to secure to all its citizens
